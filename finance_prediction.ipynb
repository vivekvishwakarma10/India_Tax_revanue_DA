# %%
# Importing lib which is required for project
import pandas as pd    #for reading dataset and related Operation
import numpy as np     #for methametics calculation
import matplotlib.pyplot as plt  # for ploting related graf or trends

# %%
df = pd.read_csv("Own_Tax_Revenues.csv", encoding="cp1255",index_col="State") #Reading dataset with help of pandas

# %%
df.head(5)    #Func for displaying top 5 values of datasets
# Out:
#                   1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# State
# Andhra Pradesh        582     703     808     965    1174    1439    1559
# Arunachal Pradesh       –       –       –       –       –       –       2
# Assam                  66      90     108     136     189     235     245
# Bihar                 277     338     382     442     464     576     659
# Chhattisgarh            –       –       –       –       –       –       –
#
#                   1987-88 1988-89 1989-90  ...  2006-07  2007-08  2008-09  \
# State                                      ...
# Andhra Pradesh       1819    2122    2384  ...  23930.0  28790.0  33360.0
# Arunachal Pradesh       2       2       2  ...     80.0    100.0    140.0
# Assam                 249     279     333  ...   3480.0   3360.0   4150.0
# Bihar                 761     831     925  ...   4030.0   5090.0   6170.0
# Chhattisgarh            –       –       –  ...   5050.0   5620.0   6590.0
#
# ...

# %%
df.info()  #Checking the info of the df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, Andhra Pradesh  to Puducherry
# Data columns (total 36 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1980-81  29 non-null     object
#  1   1981-82  29 non-null     object
#  2   1982-83  29 non-null     object
#  3   1983-84  29 non-null     object
#  4   1984-85  29 non-null     object
#  5   1985-86  29 non-null     object
#  6   1986-87  29 non-null     object
#  7   1987-88  29 non-null     object
#  8   1988-89  29 non-null     object
#  9   1989-90  29 non-null     object
#  10  1990-91  25 non-null     float64
#  11  1991-92  25 non-null     float64
#  12  1992-93  25 non-null     float64
#  13  1993-94  26 non-null     float64
#  14  1994-95  26 non-null     float64
#  15  1995-96  26 non-null     float64
#  16  1996-97  26 non-null     float64
#  17  1997-98  26 non-null     float64
#  18  1998-99  26 non-null     float64
#  19  1999-00  26 non-null     float64
# ...

# %%
df.isnull().sum()     #for findind the missing values in given dataset
# Out:
# 1980-81    2
# 1981-82    2
# 1982-83    2
# 1983-84    2
# 1984-85    2
# 1985-86    2
# 1986-87    2
# 1987-88    2
# 1988-89    2
# 1989-90    2
# 1990-91    6
# 1991-92    6
# 1992-93    6
# 1993-94    5
# 1994-95    5
# 1995-96    5
# 1996-97    5
# 1997-98    5
# 1998-99    5
# 1999-00    5
# 2000-01    3
# 2001-02    2
# 2002-03    2
# 2003-04    2
# 2004-05    2
# 2005-06    1
# 2006-07    1
# 2007-08    1
# 2008-09    1
# 2009-10    1
# 2010-11    1
# 2011-12    1
# 2012-13    1
# 2013-14    0
# 2014-15    0
# 2015-16    0
# dtype: int64

# %%
df["1980-81"].value_counts()  # Taking the values of 1980-81 from dataset
# Out:
# –       7
# 4       2
# 3       2
# 582     1
# 1130    1
# 645     1
# 639     1
# 230     1
# 349     1
# 132     1
# 5       1
# 386     1
# 337     1
# 475     1
# 38      1
# 34      1
# 234     1
# 531     1
# 277     1
# 66      1
# 514     1
# Name: 1980-81, dtype: int64

# %%
df.replace("–",0,inplace=True)
# Replacing null values to 0

# %%
df    #Printing dataset to check if " null " replaced with  "0"
# Out:
#                   1980-81 1981-82 1982-83 1983-84 1984-85 1985-86 1986-87  \
# State
# Andhra Pradesh        582     703     808     965    1174    1439    1559
# Arunachal Pradesh       0       0       0       0       0       0       2
# Assam                  66      90     108     136     189     235     245
# Bihar                 277     338     382     442     464     576     659
# Chhattisgarh            0       0       0       0       0       0       0
# Goa                     0       0       0       0       0       0      61
# Gujarat               531     661     763     879     980    1075    1264
# Haryana               234     291     337     366     406     502     566
# Himachal Pradesh       34      42      48      54      61      74      92
# Jammu & Kashmir        38      60      62      71      79     104     118
# Jharkhand               0       0       0       0       0       0       0
# Karnataka             475     607     674     760     909    1076    1206
# ...

# %%
df.info()  # again checking the info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, Andhra Pradesh  to Puducherry
# Data columns (total 36 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   1980-81  29 non-null     object
#  1   1981-82  29 non-null     object
#  2   1982-83  29 non-null     object
#  3   1983-84  29 non-null     object
#  4   1984-85  29 non-null     object
#  5   1985-86  29 non-null     object
#  6   1986-87  29 non-null     object
#  7   1987-88  29 non-null     object
#  8   1988-89  29 non-null     object
#  9   1989-90  29 non-null     object
#  10  1990-91  25 non-null     float64
#  11  1991-92  25 non-null     float64
#  12  1992-93  25 non-null     float64
#  13  1993-94  26 non-null     float64
#  14  1994-95  26 non-null     float64
#  15  1995-96  26 non-null     float64
#  16  1996-97  26 non-null     float64
#  17  1997-98  26 non-null     float64
#  18  1998-99  26 non-null     float64
#  19  1999-00  26 non-null     float64
# ...

# %%
df["1980-81"]=pd.to_numeric(df["1980-81"],downcast="float")  #for type casting

# %%
df.dtypes
# Out:
# 1980-81    float32
# 1981-82     object
# 1982-83     object
# 1983-84     object
# 1984-85     object
# 1985-86     object
# 1986-87     object
# 1987-88     object
# 1988-89     object
# 1989-90     object
# 1990-91    float64
# 1991-92    float64
# 1992-93    float64
# 1993-94    float64
# 1994-95    float64
# 1995-96    float64
# 1996-97    float64
# 1997-98    float64
# 1998-99    float64
# 1999-00    float64
# 2000-01    float64
# 2001-02    float64
# 2002-03    float64
# 2003-04    float64
# 2004-05    float64
# 2005-06    float64
# 2006-07    float64
# 2007-08    float64
# 2008-09    float64
# 2009-10    float64
# 2010-11    float64
# 2011-12    float64
# 2012-13    float64
# 2013-14      int64
# 2014-15      int64
# 2015-16      int64
# dtype: object

# %%
m=df["1980-81"].mean()  #calculating the mean of 1980*81 coloumn

# %%
df["1980-81"].replace(0,m,inplace=True)  #replacing zero to mean value

# %%
df
# Out:
#                        1980-81 1981-82 1982-83 1983-84 1984-85 1985-86  \
# State
# Andhra Pradesh      582.000000     703     808     965    1174    1439
# Arunachal Pradesh   228.206894       0       0       0       0       0
# Assam                66.000000      90     108     136     189     235
# Bihar               277.000000     338     382     442     464     576
# Chhattisgarh        228.206894       0       0       0       0       0
# Goa                 228.206894       0       0       0       0       0
# Gujarat             531.000000     661     763     879     980    1075
# Haryana             234.000000     291     337     366     406     502
# Himachal Pradesh     34.000000      42      48      54      61      74
# Jammu & Kashmir      38.000000      60      62      71      79     104
# Jharkhand           228.206894       0       0       0       0       0
# Karnataka           475.000000     607     674     760     909    1076
# ...

# %%
df["1980-81"].value_counts()
# Out:
# 228.206894     7
# 4.000000       2
# 3.000000       2
# 582.000000     1
# 1130.000000    1
# 645.000000     1
# 639.000000     1
# 230.000000     1
# 349.000000     1
# 132.000000     1
# 5.000000       1
# 386.000000     1
# 337.000000     1
# 475.000000     1
# 38.000000      1
# 34.000000      1
# 234.000000     1
# 531.000000     1
# 277.000000     1
# 66.000000      1
# 514.000000     1
# Name: 1980-81, dtype: int64

# %%
df["2014-15"]+df["2015-16"]
# Out:
# State
# Andhra Pradesh        82900
# Arunachal Pradesh      1000
# Assam                 23640
# Bihar                 56540
# Chhattisgarh          38220
# Goa                    8370
# Gujarat              130490
# Haryana               62850
# Himachal Pradesh      12040
# Jammu & Kashmir       14450
# Jharkhand             28010
# Karnataka            145000
# Kerala                83710
# Madhya Pradesh        82640
# Maharashtra          249540
# Manipur                1260
# Meghalaya              2250
# Mizoram                 600
# Nagaland                790
# Odisha                40550
# Punjab                57910
# Rajasthan             86890
# Sikkim                 1070
# Tamil Nadu           181850
# Telangana             81880
# Tripura                2560
# Uttar Pradesh        167890
# Uttarakhand           17660
# West Bengal           86560
# Delhi                 62330
# Puducherry             4370
# dtype: int64

# %%
north=df.loc["Uttar Pradesh","2015-16"]+df.loc["Delhi","2015-16"]+df.loc["Haryana","2015-16"]+df.loc["Punjab","2015-16"]

# %%
north
# Out:
# 189180

# %%
df.index
# Out:
# Index(['Andhra Pradesh ', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chhattisgarh', 'Goa', 'Gujarat', 'Haryana', 'Himachal Pradesh',
#        'Jammu & Kashmir', 'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Delhi', 'Puducherry'],
#       dtype='object', name='State')

# %%
south=df.loc["Tamil Nadu","2015-16"]+df.loc["Karnataka","2015-16"]+df.loc["Andhra Pradesh ","2015-16"]+df.loc["Kerala","2015-16"]

# %%
south
# Out:
# 262380

# %%
d={"North":north,"South":south}

# %%
plt.pie(d.values(),labels=d.keys(),autopct="%1.1f%%",textprops={"color":"w"})
plt.show()

#for displaying the total tax_revanue of india according to south and north side state of country
